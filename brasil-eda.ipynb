# %% [markdown]
# ### crea un dataframe con los resultados de la EDA para cada uno de los anios

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

## https://www.ibge.gov.br/en/home-eng.html

# %%
from funciones_soporte import *

# %%
years = range(2013,2022)

df_columns_names = pd.DataFrame()

for y in years:
    df_datos = pd.read_csv(f"datos\datos-{y}.csv", sep= ";", encoding='latin-1')
    df_columns_names[y] = df_datos.columns

df_columns_names
# Out:
#                          2013                       2014  \
# 0       CÓDIGO ÓRGÃO SUPERIOR      CÓDIGO ÓRGÃO SUPERIOR
# 1         NOME ÓRGÃO SUPERIOR        NOME ÓRGÃO SUPERIOR
# 2                CÓDIGO ÓRGÃO               CÓDIGO ÓRGÃO
# 3                  NOME ÓRGÃO                 NOME ÓRGÃO
# 4      CÓDIGO UNIDADE GESTORA     CÓDIGO UNIDADE GESTORA
# 5        NOME UNIDADE GESTORA       NOME UNIDADE GESTORA
# 6         CATEGORIA ECONÔMICA        CATEGORIA ECONÔMICA
# 7              ORIGEM RECEITA             ORIGEM RECEITA
# 8             ESPÉCIE RECEITA            ESPÉCIE RECEITA
# 9                DETALHAMENTO               DETALHAMENTO
# 10  VALOR PREVISTO ATUALIZADO  VALOR PREVISTO ATUALIZADO
# 11              VALOR LANÇADO              VALOR LANÇADO
# 12            VALOR REALIZADO            VALOR REALIZADO
# 13       PERCENTUAL REALIZADO       PERCENTUAL REALIZADO
# 14            DATA LANÇAMENTO            DATA LANÇAMENTO
# 15              ANO EXERCÍCIO              ANO EXERCÍCIO
#
#                          2015                       2016  \
# 0       CÓDIGO ÓRGÃO SUPERIOR      CÓDIGO ÓRGÃO SUPERIOR
# 1         NOME ÓRGÃO SUPERIOR        NOME ÓRGÃO SUPERIOR
# 2                CÓDIGO ÓRGÃO               CÓDIGO ÓRGÃO
# 3                  NOME ÓRGÃO                 NOME ÓRGÃO
# 4      CÓDIGO UNIDADE GESTORA     CÓDIGO UNIDADE GESTORA
# 5        NOME UNIDADE GESTORA       NOME UNIDADE GESTORA
# 6         CATEGORIA ECONÔMICA        CATEGORIA ECONÔMICA
# 7              ORIGEM RECEITA             ORIGEM RECEITA
# 8             ESPÉCIE RECEITA            ESPÉCIE RECEITA
# 9                DETALHAMENTO               DETALHAMENTO
# 10  VALOR PREVISTO ATUALIZADO  VALOR PREVISTO ATUALIZADO
# 11              VALOR LANÇADO              VALOR LANÇADO
# 12            VALOR REALIZADO            VALOR REALIZADO
# 13       PERCENTUAL REALIZADO       PERCENTUAL REALIZADO
# 14            DATA LANÇAMENTO            DATA LANÇAMENTO
# 15              ANO EXERCÍCIO              ANO EXERCÍCIO
#
#                          2017                       2018  \
# 0       CÓDIGO ÓRGÃO SUPERIOR      CÓDIGO ÓRGÃO SUPERIOR
# 1         NOME ÓRGÃO SUPERIOR        NOME ÓRGÃO SUPERIOR
# 2                CÓDIGO ÓRGÃO               CÓDIGO ÓRGÃO
# 3                  NOME ÓRGÃO                 NOME ÓRGÃO
# 4      CÓDIGO UNIDADE GESTORA     CÓDIGO UNIDADE GESTORA
# 5        NOME UNIDADE GESTORA       NOME UNIDADE GESTORA
# 6         CATEGORIA ECONÔMICA        CATEGORIA ECONÔMICA
# 7              ORIGEM RECEITA             ORIGEM RECEITA
# 8             ESPÉCIE RECEITA            ESPÉCIE RECEITA
# 9                DETALHAMENTO               DETALHAMENTO
# 10  VALOR PREVISTO ATUALIZADO  VALOR PREVISTO ATUALIZADO
# 11              VALOR LANÇADO              VALOR LANÇADO
# 12            VALOR REALIZADO            VALOR REALIZADO
# 13       PERCENTUAL REALIZADO       PERCENTUAL REALIZADO
# 14            DATA LANÇAMENTO            DATA LANÇAMENTO
# 15              ANO EXERCÍCIO              ANO EXERCÍCIO
#
#                          2019                       2020  \
# 0       CÓDIGO ÓRGÃO SUPERIOR      CÓDIGO ÓRGÃO SUPERIOR
# 1         NOME ÓRGÃO SUPERIOR        NOME ÓRGÃO SUPERIOR
# 2                CÓDIGO ÓRGÃO               CÓDIGO ÓRGÃO
# 3                  NOME ÓRGÃO                 NOME ÓRGÃO
# 4      CÓDIGO UNIDADE GESTORA     CÓDIGO UNIDADE GESTORA
# 5        NOME UNIDADE GESTORA       NOME UNIDADE GESTORA
# 6         CATEGORIA ECONÔMICA        CATEGORIA ECONÔMICA
# 7              ORIGEM RECEITA             ORIGEM RECEITA
# 8             ESPÉCIE RECEITA            ESPÉCIE RECEITA
# 9                DETALHAMENTO               DETALHAMENTO
# 10  VALOR PREVISTO ATUALIZADO  VALOR PREVISTO ATUALIZADO
# 11              VALOR LANÇADO              VALOR LANÇADO
# 12            VALOR REALIZADO            VALOR REALIZADO
# 13       PERCENTUAL REALIZADO       PERCENTUAL REALIZADO
# 14            DATA LANÇAMENTO            DATA LANÇAMENTO
# 15              ANO EXERCÍCIO              ANO EXERCÍCIO
#
#                          2021
# 0       CÓDIGO ÓRGÃO SUPERIOR
# 1         NOME ÓRGÃO SUPERIOR
# 2                CÓDIGO ÓRGÃO
# 3                  NOME ÓRGÃO
# 4      CÓDIGO UNIDADE GESTORA
# 5        NOME UNIDADE GESTORA
# 6         CATEGORIA ECONÔMICA
# 7              ORIGEM RECEITA
# 8             ESPÉCIE RECEITA
# 9                DETALHAMENTO
# 10  VALOR PREVISTO ATUALIZADO
# 11              VALOR LANÇADO
# 12            VALOR REALIZADO
# 13       PERCENTUAL REALIZADO
# 14            DATA LANÇAMENTO
# 15              ANO EXERCÍCIO

# %% [markdown]
# #### Con el loop anterior, podemos ver que todas las columnas son del mismo tipo

# %% [markdown]
# ## Ahora vamos a explorar si hay datos nulos

# %%
years = range(2013,2022)

df_info_isna = pd.DataFrame()

for y in years:
    df_datos = pd.read_csv(f"datos\datos-{y}.csv", sep= ";", encoding='latin-1')
    df_info_isna[y] = df_datos.isna().sum()

df_info_isna
# Out:
#                            2013  2014  2015  2016  2017  2018  2019  2020  \
# CÓDIGO ÓRGÃO SUPERIOR         0     0     0     0     0     0     0     0
# NOME ÓRGÃO SUPERIOR           0     0     0     0     0     0     0     0
# CÓDIGO ÓRGÃO                  0     0     0     0     0     0     0     0
# NOME ÓRGÃO                    0     0     0     0     0     0     0     0
# CÓDIGO UNIDADE GESTORA        0     0     0     0     0     0     0     0
# NOME UNIDADE GESTORA          0     0     0     0     0     0     0     0
# CATEGORIA ECONÔMICA           0     0     0     0     0     0     0     0
# ORIGEM RECEITA                0     0     0     0     0     0     0     0
# ESPÉCIE RECEITA               0     0     0     0     0     0     0     0
# DETALHAMENTO                  0     0     0     0     0     0     0     0
# VALOR PREVISTO ATUALIZADO     0     0     0     0     0     0     0     0
# VALOR LANÇADO                 0     0     0     0     0     0     0     0
# VALOR REALIZADO               0     0     0     0     0     0     0     0
# PERCENTUAL REALIZADO          0     0     0     0     0     0     0     0
# DATA LANÇAMENTO               0     0     0    82    86   115    86    86
# ANO EXERCÍCIO                 0     0     0     0     0     0     0     0
#
#                            2021
# CÓDIGO ÓRGÃO SUPERIOR         0
# NOME ÓRGÃO SUPERIOR           0
# CÓDIGO ÓRGÃO                  0
# NOME ÓRGÃO                    0
# CÓDIGO UNIDADE GESTORA        0
# NOME UNIDADE GESTORA          0
# CATEGORIA ECONÔMICA           0
# ORIGEM RECEITA                0
# ESPÉCIE RECEITA               0
# DETALHAMENTO                  0
# VALOR PREVISTO ATUALIZADO     0
# VALOR LANÇADO                 0
# VALOR REALIZADO               0
# PERCENTUAL REALIZADO          0
# DATA LANÇAMENTO             123
# ANO EXERCÍCIO                 0

# %% [markdown]
# #### Con lo anterior, sabemos que la columnas de DATA LANCAMENTO tiene nulos a partir de 2016

# %%
import pandas as pd

years = range(2013, 2022)
df_info_type = pd.DataFrame()

info_dict = {}  ## no logro meter el resultado de datainfo en un dataframe, pero si puedo hacerlo en un diccionario

for y in years:
    df_datos = pd.read_csv(f"datos/datos-{y}.csv", sep=";", encoding='latin-1')
    info_dict[y] = {
        'column_names': df_datos.columns.tolist(),
        'data_types': df_datos.dtypes.tolist()}

# Despues puedo convertir el diccionario en un dataframeexplorar el diccionario columna a columna y ver si el tipo de datos para cada anio es el mismo
for year, sub_dict in info_dict.items():
    for key, value in sub_dict.items():
        print(value[15])
# Out:
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64
# ANO EXERCÍCIO
# int64

# %% [markdown]
# #### Despues de revisar los tipos de datos anteriores, todo parece correcto y todas las columnas tienen el mismo tipo de dato.

# %% [markdown]
# ### Visto todo lo anterior, me dispongo a unir el dataframe

# %%
#https://stackoverflow.com/questions/11479392/what-does-a-for-loop-within-a-list-do-in-python  buscando como hacer el loop mas eficiente

year = range(2013, 2022)

lista_df = [pd.read_csv(f"datos/datos-{y}.csv", sep=";", encoding='latin-1') for y in year]

df_all = pd.concat(lista_df, axis=0)  ## concat admite una lista de dataframes

df_all.columns
# Out:
# Index(['CÓDIGO ÓRGÃO SUPERIOR', 'NOME ÓRGÃO SUPERIOR', 'CÓDIGO ÓRGÃO',
#        'NOME ÓRGÃO', 'CÓDIGO UNIDADE GESTORA', 'NOME UNIDADE GESTORA',
#        'CATEGORIA ECONÔMICA', 'ORIGEM RECEITA', 'ESPÉCIE RECEITA',
#        'DETALHAMENTO', 'VALOR PREVISTO ATUALIZADO', 'VALOR LANÇADO',
#        'VALOR REALIZADO', 'PERCENTUAL REALIZADO', 'DATA LANÇAMENTO',
#        'ANO EXERCÍCIO'],
#       dtype='object')

# %%
## https://www.statology.org/pandas-rename-columns-with-dictionary/

## Renombrar columnas del dataframe df_all

column_translation_dict = {
 'CÓDIGO ÓRGÃO SUPERIOR': 'codigo_organo_superior',
 'NOME ÓRGÃO SUPERIOR': 'nombre_organo_superior',
 'CÓDIGO ÓRGÃO': 'codigo_organo',
 'NOME ÓRGÃO': 'nombre_organo',
 'CÓDIGO UNIDADE GESTORA': 'codigo_unidad_gestora',
 'NOME UNIDADE GESTORA': 'nombre_unidad_gestora',
 'CATEGORIA ECONÔMICA': 'categoria_economica',
 'ORIGEM RECEITA': 'origen_receta',
 'ESPÉCIE RECEITA': 'especie_receta',
 'DETALHAMENTO': 'detallamiento',
 'VALOR PREVISTO ATUALIZADO': 'valor_previsto_actualizado',
 'VALOR LANÇADO': 'valor_lanzado',
 'VALOR REALIZADO': 'valor_realizado',
 'PERCENTUAL REALIZADO': 'percentual_realizado',
 'DATA LANÇAMENTO': 'fecha_lanzamiento',
 'ANO EXERCÍCIO': 'ano_ejercicio'
}



#define dictionary
#rename columns in DataFrame using dictionary

df_all.rename(columns=column_translation_dict, inplace=True)

df_all.columns

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1026299 entries, 0 to 134592
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   codigo_organo_superior      1026299 non-null  int64
#  1   nombre_organo_superior      1026299 non-null  object
#  2   codigo_organo               1026299 non-null  int64
#  3   nombre_organo               1026299 non-null  object
#  4   codigo_unidad_gestora       1026299 non-null  int64
#  5   nombre_unidad_gestora       1026299 non-null  object
#  6   categoria_economica         1026299 non-null  object
#  7   origen_receta               1026299 non-null  object
#  8   especie_receta              1026299 non-null  object
#  9   detallamiento               1026299 non-null  object
#  10  valor_previsto_actualizado  1026299 non-null  object
#  11  valor_lanzado               1026299 non-null  object
#  12  valor_realizado             1026299 non-null  object
#  13  percentual_realizado        1026299 non-null  object
#  14  fecha_lanzamiento           1025721 non-null  object
#  15  ano_ejercicio               1026299 non-null  int64
# dtypes: int64(4), object(12)
# memory usage: 133.1+ MB

# %% [markdown]
# ## Revisar las columnas, tipos de datos

# %%
#df_all.isna().sum()

#df_all.info()

#null_mask = df_all.isnull().any(axis=1)
#null_rows = df_all[null_mask]

#print(null_rows)
## https://stackoverflow.com/questions/8420143/valueerror-could-not-convert-string-to-float-id

df_all["valor_previsto_actualizado"] = [float(str(i).replace(",", ".")) for i in df_all["valor_previsto_actualizado"]]
df_all['valor_previsto_actualizado'] = df_all['valor_previsto_actualizado'].astype('float')


df_all["valor_realizado"] = [float(str(i).replace(",", ".")) for i in df_all["valor_realizado"]]
df_all['valor_realizado'] = df_all['valor_realizado'].astype('float')

df_all["valor_lanzado"] = [float(str(i).replace(",", ".")) for i in df_all["valor_lanzado"]]
df_all['valor_lanzado'] = df_all['valor_lanzado'].astype('float')


df_all["percentual_realizado"] = [float(str(i).replace(",", ".")) for i in df_all["percentual_realizado"]]
df_all['percentual_realizado'] = df_all['percentual_realizado'].astype('float')

df_all['ano_ejercicio'] = df_all['ano_ejercicio'].astype('int')

df_all['codigo_organo_superior'] = df_all['codigo_organo_superior'].astype('str')
df_all['codigo_organo'] = df_all['codigo_organo'].astype('str')
df_all['codigo_unidad_gestora'] = df_all['codigo_unidad_gestora'].astype('str')

df_all['fecha_lanzamiento'] = pd.to_datetime(df_all['fecha_lanzamiento'], format="%d/%m/%Y")

#df_porcentaje_uniques = df_all['PORCENTAJE REALIZADO'].unique()
#df_porcentaje_uniques

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1026299 entries, 0 to 134592
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   codigo_organo_superior      1026299 non-null  object
#  1   nombre_organo_superior      1026299 non-null  object
#  2   codigo_organo               1026299 non-null  object
#  3   nombre_organo               1026299 non-null  object
#  4   codigo_unidad_gestora       1026299 non-null  object
#  5   nombre_unidad_gestora       1026299 non-null  object
#  6   categoria_economica         1026299 non-null  object
#  7   origen_receta               1026299 non-null  object
#  8   especie_receta              1026299 non-null  object
#  9   detallamiento               1026299 non-null  object
#  10  valor_previsto_actualizado  1026299 non-null  float64
#  11  valor_lanzado               1026299 non-null  float64
#  12  valor_realizado             1026299 non-null  float64
#  13  percentual_realizado        1026299 non-null  float64
#  14  fecha_lanzamiento           1025721 non-null  datetime64[ns]
#  15  ano_ejercicio               1026299 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(1), object(10)
# memory usage: 129.2+ MB

# %% [markdown]
# ## Revisar los nulos

# %%
df_all.isnull().sum()
# Out:
# codigo_organo_superior          0
# nombre_organo_superior          0
# codigo_organo                   0
# nombre_organo                   0
# codigo_unidad_gestora           0
# nombre_unidad_gestora           0
# categoria_economica             0
# origen_receta                   0
# especie_receta                  0
# detallamiento                   0
# valor_previsto_actualizado      0
# valor_lanzado                   0
# valor_realizado                 0
# percentual_realizado            0
# fecha_lanzamiento             578
# ano_ejercicio                   0
# dtype: int64

# %% [markdown]
# ### Calcular el porcentaje de nulos

# %%
df_porcentaje_uniques = df_all['fecha_lanzamiento'].unique()
df_porcentaje_uniques

df_nulos_anio = df_all.fecha_lanzamiento.isnull().groupby([df_all['ano_ejercicio']]).sum().astype(int).reset_index(name='total_nulls')
print(df_nulos_anio)

df_total_anio = df_all.groupby(['ano_ejercicio'])['ano_ejercicio'].count().reset_index(name='total_records')
print(df_total_anio)

df_merge_anios = pd.merge(df_nulos_anio, df_total_anio, on="ano_ejercicio")

df_merge_anios["anio_percentage_null"] = (df_merge_anios["total_nulls"]/df_merge_anios["total_records"])*100

df_merge_anios
# Out:
#    ano_ejercicio  total_nulls
# 0           2013            0
# 1           2014            0
# 2           2015            0
# 3           2016           82
# 4           2017           86
# 5           2018          115
# 6           2019           86
# 7           2020           86
# 8           2021          123
#    ano_ejercicio  total_records
# 0           2013           4498
# 1           2014           4553
# 2           2015           4523
# 3           2016         194533
# 4           2017         190479
# 5           2018         173944
# 6           2019         176828
# 7           2020         142348
# 8           2021         134593
#    ano_ejercicio  total_nulls  total_records  anio_percentage_null
# 0           2013            0           4498              0.000000
# 1           2014            0           4553              0.000000
# 2           2015            0           4523              0.000000
# 3           2016           82         194533              0.042152
# 4           2017           86         190479              0.045149
# 5           2018          115         173944              0.066113
# 6           2019           86         176828              0.048635
# 7           2020           86         142348              0.060415
# 8           2021          123         134593              0.091387

# %% [markdown]
# ### Teniendo en cuenta en lo anterior, parece que el numero de nulos es bastante marginal, menos del 0,1% para todos los casos. Por ello decido eliminarlos.

# %%
# https://www.w3schools.com/python/pandas/ref_df_dropna.asp#:~:text=The%20dropna()%20method%20removes,in%20the%20original%20DataFrame%20instead.

df_all = df_all.dropna()

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1025721 entries, 0 to 134592
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   codigo_organo_superior      1025721 non-null  object
#  1   nombre_organo_superior      1025721 non-null  object
#  2   codigo_organo               1025721 non-null  object
#  3   nombre_organo               1025721 non-null  object
#  4   codigo_unidad_gestora       1025721 non-null  object
#  5   nombre_unidad_gestora       1025721 non-null  object
#  6   categoria_economica         1025721 non-null  object
#  7   origen_receta               1025721 non-null  object
#  8   especie_receta              1025721 non-null  object
#  9   detallamiento               1025721 non-null  object
#  10  valor_previsto_actualizado  1025721 non-null  float64
#  11  valor_lanzado               1025721 non-null  float64
#  12  valor_realizado             1025721 non-null  float64
#  13  percentual_realizado        1025721 non-null  float64
#  14  fecha_lanzamiento           1025721 non-null  datetime64[ns]
#  15  ano_ejercicio               1025721 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(1), object(10)
# memory usage: 129.1+ MB

# %% [markdown]
# ## Ahora que tengo mis datos mas ordenados, vamos a usar describe()

# %%
df_all.describe().T
# Out:
#                                 count                           mean  \
# valor_previsto_actualizado  1025721.0                27626980.252787
# valor_lanzado               1025721.0                 2712342.560349
# valor_realizado             1025721.0                24994498.928506
# percentual_realizado        1025721.0                      80.359069
# fecha_lanzamiento             1025721  2018-09-20 12:23:18.569787136
# ano_ejercicio               1025721.0                    2018.225315
#
#                                             min                  25%  \
# valor_previsto_actualizado         -214773743.0                  0.0
# valor_lanzado              -148347267246.910004                  0.0
# valor_realizado            -156285934188.029999                262.5
# percentual_realizado                  -114552.0                  0.0
# fecha_lanzamiento           2013-12-31 00:00:00  2017-03-31 00:00:00
# ano_ejercicio                            2013.0               2017.0
#
#                                             50%                  75%  \
# valor_previsto_actualizado                  0.0                  0.0
# valor_lanzado                               0.0                  0.0
# valor_realizado                          3030.0              40932.5
# percentual_realizado                        0.0                  0.0
# fecha_lanzamiento           2018-08-27 00:00:00  2020-02-12 00:00:00
# ano_ejercicio                            2018.0               2020.0
#
#                                             max                std
# valor_previsto_actualizado      1603521711208.0  3394323069.572854
# valor_lanzado               357160677863.969971   698431477.240617
# valor_realizado             771117711060.949951  1407288764.633113
# percentual_realizado                 72363772.0       71501.250083
# fecha_lanzamiento           2021-12-03 00:00:00                NaN
# ano_ejercicio                            2021.0           1.737948

# %% [markdown]
# ## Analizo tambien los valores distintos de los elemenos no numericos

# %%
df_all.nunique()
# Out:
# codigo_organo_superior            25
# nombre_organo_superior            25
# codigo_organo                    291
# nombre_organo                    287
# codigo_unidad_gestora            364
# nombre_unidad_gestora            356
# categoria_economica                5
# origen_receta                     15
# especie_receta                    63
# detallamiento                   1886
# valor_previsto_actualizado     18588
# valor_lanzado                   6351
# valor_realizado               605783
# percentual_realizado             971
# fecha_lanzamiento               2157
# ano_ejercicio                      9
# dtype: int64

# %%
## https://stackoverflow.com/questions/22470690/get-list-of-pandas-dataframe-columns-based-on-data-type

# Pongo los elementos unicos categoricos en un diccionario

# Primero creo una lista con los nombres de las columnas

lista_columnas = list(df_all.select_dtypes(['object']).columns)

# Creo un diccionario vacio

dict_uniques = {}

# Itero las columnas y extraigo los elementos unicos de cada una de ellas

for columna in lista_columnas:
    dict_uniques[columna] = df_all[columna].unique() # El nombre de la columna es la key y la lista de elementos unicos son los valores 

print(dict_uniques['detallamiento'])
# Out:
# ['REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC'
#  'RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES'
#  'OUTRAS MULTAS E JUROS DE MORA' ...
#  'UTIL.REC.HID-DEM.EMPRESAS-PRORROG.OUT-PRINC.'
#  'OUTORGA DIR.USO DE RECURSOS HIDRICOS-DIV.AT.'
#  'RECEITA INDUSTRIAL-DIVIDA ATIVA']

# %% [markdown]
# ## Mas highlevel info

# %%
df_all.sort_values(by="valor_previsto_actualizado", ascending=False).head()
# Out:
#       codigo_organo_superior  nombre_organo_superior codigo_organo  \
# 40355                  25000  Ministério da Economia         25000
# 41056                  25000  Ministério da Economia         25000
# 59204                  25000  Ministério da Economia         25000
# 45738                  25000  Ministério da Economia         25000
# 1212                   25000  Ministério da Economia         25000
#
#                                            nombre_organo  \
# 40355  Ministério da Economia - Unidades com vínculo ...
# 41056  Ministério da Economia - Unidades com vínculo ...
# 59204  Ministério da Economia - Unidades com vínculo ...
# 45738  Ministério da Economia - Unidades com vínculo ...
# 1212   Ministério da Economia - Unidades com vínculo ...
#
#       codigo_unidad_gestora                    nombre_unidad_gestora  \
# 40355                170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 41056                170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 59204                170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 45738                170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 1212                 170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
#
#        categoria_economica         origen_receta  \
# 40355  Receitas de Capital  Operações de Crédito
# 41056  Receitas de Capital  Operações de Crédito
# 59204  Receitas de Capital  Operações de Crédito
# 45738  Receitas de Capital  Operações de Crédito
# 1212   Receitas de Capital  Operações de Crédito
#
#                                especie_receta  \
# 40355  Operações de crédito - mercado interno
# 41056  Operações de crédito - mercado interno
# 59204  Operações de crédito - mercado interno
# 45738  Operações de crédito - mercado interno
# 1212   Operações de crédito - mercado interno
#
#                                        detallamiento  \
# 40355  TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.INT.-PRINC
# 41056  TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.INT.-PRINC
# 59204  TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.INT.-PRINC
# 45738  TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.INT.-PRINC
# 1212   TIT.RESP.T.N.-REFINANC.DIVIDA PUBLICA FEDERAL
#
#        valor_previsto_actualizado  valor_lanzado  valor_realizado  \
# 40355                1.603522e+12            0.0     1.929656e+10
# 41056                1.130479e+12            0.0     6.724889e+09
# 59204                9.250845e+11            0.0     9.708341e+07
# 45738                9.156509e+11            0.0     8.209641e+07
# 1212                 9.020289e+11            0.0     7.711177e+11
#
#        percentual_realizado fecha_lanzamiento  ano_ejercicio
# 40355                   1.0        2021-04-23           2021
# 41056                   1.0        2018-01-12           2018
# 59204                   0.0        2017-01-19           2017
# 45738                   0.0        2020-01-20           2020
# 1212                   85.0        2015-12-31           2015

# %%
df_all.sort_values(by="valor_lanzado", ascending=False).head()
# Out:
#      codigo_organo_superior  nombre_organo_superior codigo_organo  \
# 1246                  25000  Ministério da Economia         25000
# 725                   25000  Ministério da Economia         25000
# 959                   25000  Ministério da Economia         25000
# 619                   25000  Ministério da Economia         25000
# 1203                  25000  Ministério da Economia         25000
#
#                                           nombre_organo codigo_unidad_gestora  \
# 1246  Ministério da Economia - Unidades com vínculo ...                170010
# 725   Ministério da Economia - Unidades com vínculo ...                170010
# 959   Ministério da Economia - Unidades com vínculo ...                170010
# 619   Ministério da Economia - Unidades com vínculo ...                170010
# 1203  Ministério da Economia - Unidades com vínculo ...                170010
#
#                             nombre_unidad_gestora categoria_economica  \
# 1246  SECRETARIA DA RECEITA FEDERAL DO BRASIL-RFB  Receitas Correntes
# 725   SECRETARIA DA RECEITA FEDERAL DO BRASIL-RFB  Receitas Correntes
# 959   SECRETARIA DA RECEITA FEDERAL DO BRASIL-RFB  Receitas Correntes
# 619   SECRETARIA DA RECEITA FEDERAL DO BRASIL-RFB  Receitas Correntes
# 1203  SECRETARIA DA RECEITA FEDERAL DO BRASIL-RFB  Receitas Correntes
#
#                                     origen_receta         especie_receta  \
# 1246  Impostos, Taxas e Contribuições de Melhoria               Impostos
# 725   Impostos, Taxas e Contribuições de Melhoria               Impostos
# 959                                 Contribuições  Contribuições sociais
# 619                                 Contribuições  Contribuições sociais
# 1203                                Contribuições  Contribuições sociais
#
#                                       detallamiento  \
# 1246      PESSOAS JURIDICAS - LIQUIDA DE INCENTIVOS
# 725       PESSOAS JURIDICAS - LIQUIDA DE INCENTIVOS
# 959   REC.DO PRINCIPAL DA CONTR. P FIN. SEG. SOCIAL
# 619   REC.DO PRINCIPAL DA CONTR. P FIN. SEG. SOCIAL
# 1203        REC. DO PRINCIPAL DA CONTRIB S/LUCRO PJ
#
#       valor_previsto_actualizado  valor_lanzado  valor_realizado  \
# 1246                         0.0   3.571607e+11              0.0
# 725                          0.0   2.956063e+11              0.0
# 959                          0.0   2.196469e+11              0.0
# 619                          0.0   1.896737e+11              0.0
# 1203                         0.0   1.718016e+11              0.0
#
#       percentual_realizado fecha_lanzamiento  ano_ejercicio
# 1246                   0.0        2014-12-31           2014
# 725                    0.0        2013-12-31           2013
# 959                    0.0        2014-12-31           2014
# 619                    0.0        2013-12-31           2013
# 1203                   0.0        2014-12-31           2014

# %%
df_all.sort_values(by="valor_realizado", ascending=False).head()
# Out:
#       codigo_organo_superior  nombre_organo_superior codigo_organo  \
# 1212                   25000  Ministério da Economia         25000
# 774                    25000  Ministério da Economia         25000
# 1177                   25000  Ministério da Economia         25000
# 62959                  25000  Ministério da Economia         25000
# 948                    25000  Ministério da Economia         25000
#
#                                            nombre_organo  \
# 1212   Ministério da Economia - Unidades com vínculo ...
# 774    Ministério da Economia - Unidades com vínculo ...
# 1177   Ministério da Economia - Unidades com vínculo ...
# 62959  Ministério da Economia - Unidades com vínculo ...
# 948    Ministério da Economia - Unidades com vínculo ...
#
#       codigo_unidad_gestora                    nombre_unidad_gestora  \
# 1212                 170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 774                  170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 1177                 170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 62959                170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 948                  170013  SETORIAL ORCAMENTARIA E FINANCEIRA / ME
#
#        categoria_economica               origen_receta  \
# 1212   Receitas de Capital        Operações de Crédito
# 774    Receitas de Capital        Operações de Crédito
# 1177   Receitas de Capital        Operações de Crédito
# 62959  Receitas de Capital  Outras Receitas de Capital
# 948    Receitas de Capital        Operações de Crédito
#
#                                especie_receta  \
# 1212   Operações de crédito - mercado interno
# 774    Operações de crédito - mercado interno
# 1177   Operações de crédito - mercado interno
# 62959    Resultado do Banco Central do Brasil
# 948    Operações de crédito - mercado interno
#
#                                        detallamiento  \
# 1212   TIT.RESP.T.N.-REFINANC.DIVIDA PUBLICA FEDERAL
# 774    TIT.RESP.T.N.-REFINANC.DIVIDA PUBLICA FEDERAL
# 1177   TIT.RESP.T.N.-REFINANC.DIVIDA PUBLICA FEDERAL
# 62959  RESULTADO DO BACEN-DEMAIS OPERACOES-PRINCIPAL
# 948       TIT. RESP. DO TES.NAC. - OUTRAS APLICACOES
#
#        valor_previsto_actualizado  valor_lanzado  valor_realizado  \
# 1212                 9.020289e+11            0.0     7.711177e+11
# 774                  6.547469e+11            0.0     5.484912e+11
# 1177                 6.100657e+11            0.0     4.137862e+11
# 62959                0.000000e+00            0.0     3.500223e+11
# 948                  1.941194e+11            0.0     2.678112e+11
#
#        percentual_realizado fecha_lanzamiento  ano_ejercicio
# 1212                   85.0        2015-12-31           2015
# 774                    84.0        2014-12-31           2014
# 1177                   68.0        2013-12-31           2013
# 62959                   0.0        2020-08-28           2020
# 948                   138.0        2014-12-31           2014

# %% [markdown]
# ### Correlaciones

# %%
df_floats_call = df_all[list(df_all.select_dtypes(['float','datetime64','int']).columns)].corr()
df_floats_call
# Out:
#                             valor_previsto_actualizado  valor_lanzado  \
# valor_previsto_actualizado                    1.000000      -0.000032
# valor_lanzado                                -0.000032       1.000000
# valor_realizado                               0.368669      -0.000069
# percentual_realizado                         -0.000006      -0.000004
# fecha_lanzamiento                            -0.004336      -0.008979
# ano_ejercicio                                -0.003607      -0.010097
#
#                             valor_realizado  percentual_realizado  \
# valor_previsto_actualizado         0.368669             -0.000006
# valor_lanzado                     -0.000069             -0.000004
# valor_realizado                    1.000000              0.000182
# percentual_realizado               0.000182              1.000000
# fecha_lanzamiento                 -0.005924             -0.002429
# ano_ejercicio                     -0.007394             -0.002752
#
#                             fecha_lanzamiento  ano_ejercicio
# valor_previsto_actualizado          -0.004336      -0.003607
# valor_lanzado                       -0.008979      -0.010097
# valor_realizado                     -0.005924      -0.007394
# percentual_realizado                -0.002429      -0.002752
# fecha_lanzamiento                    1.000000       0.986145
# ano_ejercicio                        0.986145       1.000000

# %%
## https://stackoverflow.com/questions/54506626/how-to-understand-seaborns-heatmap-annotation-format
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap((df_floats_call), annot = True,fmt=".2f",ax=ax)  ## que ponga las etiquetas y 2 decimales
plt.show()

# %% [markdown]
# ## Agrupando algunas columnas para entender mejor los datos

# %%
df_all.groupby('nombre_organo_superior').mean(numeric_only=True) ##https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.mean.html
# Out:
#                                                valor_previsto_actualizado  \
# nombre_organo_superior
# Advocacia-Geral da União                                     9.556434e+05
# Controladoria-Geral da União                                 2.939257e+06
# Ministério da Agricultura, Pecuária e Abastec                1.894475e+06
# Ministério da Cidadania                                      7.453185e+06
# Ministério da Ciência, Tecnologia, Inovações                 1.895514e+06
# Ministério da Defesa                                         2.078990e+06
# Ministério da Economia                                       1.278950e+08
# Ministério da Educação                                       1.684558e+06
# Ministério da Infraestrutura                                 3.201326e+06
# Ministério da Justiça e Segurança Pública                    9.080742e+05
# Ministério da Mulher, Família e Direitos Huma                7.289256e+05
# Ministério da Pesca e Aquicultura                            1.097566e+05
# Ministério da Previdência Social                             3.488542e+05
# Ministério da Saúde                                          1.399368e+06
# Ministério das Comunicações                                  1.706183e+06
# Ministério das Mulheres, Igualdade Racial, da                3.849109e+05
# Ministério das Relações Exteriores                           1.495576e+06
# Ministério de Minas e Energia                                1.073631e+07
# Ministério do Desenvolvimento Agrário                        8.383717e+05
# Ministério do Desenvolvimento Regional                       3.849267e+06
# Ministério do Esporte                                        8.225149e+05
# Ministério do Meio Ambiente                                  4.459850e+05
# Ministério do Trabalho e Emprego                             2.091799e+07
# Ministério do Turismo                                        5.104522e+05
# Presidência da República                                     1.288803e+07
#
#                                                valor_lanzado  valor_realizado  \
# nombre_organo_superior
# Advocacia-Geral da União                        0.000000e+00     8.590997e+04
# Controladoria-Geral da União                    0.000000e+00     2.998031e+04
# Ministério da Agricultura, Pecuária e Abastec   0.000000e+00     1.221964e+06
# Ministério da Cidadania                         0.000000e+00     8.720563e+05
# Ministério da Ciência, Tecnologia, Inovações    0.000000e+00     1.059317e+06
# Ministério da Defesa                            0.000000e+00     1.096091e+06
# Ministério da Economia                          1.341972e+07     1.193160e+08
# Ministério da Educação                          1.988454e+00     6.123503e+05
# Ministério da Infraestrutura                    0.000000e+00     3.634510e+06
# Ministério da Justiça e Segurança Pública       0.000000e+00     6.307943e+05
# Ministério da Mulher, Família e Direitos Huma   0.000000e+00     1.829638e+05
# Ministério da Pesca e Aquicultura               0.000000e+00     1.548239e+05
# Ministério da Previdência Social                0.000000e+00     1.330914e+05
# Ministério da Saúde                             2.386014e+01     1.133327e+06
# Ministério das Comunicações                     0.000000e+00     1.358334e+06
# Ministério das Mulheres, Igualdade Racial, da   0.000000e+00     4.801606e+05
# Ministério das Relações Exteriores              0.000000e+00     8.228781e+05
# Ministério de Minas e Energia                   8.886242e+04     5.803659e+06
# Ministério do Desenvolvimento Agrário           0.000000e+00     7.732037e+05
# Ministério do Desenvolvimento Regional          0.000000e+00     5.914893e+05
# Ministério do Esporte                           0.000000e+00     3.666411e+05
# Ministério do Meio Ambiente                     0.000000e+00     2.625584e+05
# Ministério do Trabalho e Emprego                0.000000e+00     1.968520e+07
# Ministério do Turismo                           6.033896e+02     4.996544e+05
# Presidência da República                        0.000000e+00     3.314277e+06
#
#                                                percentual_realizado  \
# nombre_organo_superior
# Advocacia-Geral da União                                   0.180816
# Controladoria-Geral da União                               0.000000
# Ministério da Agricultura, Pecuária e Abastec              1.518806
# Ministério da Cidadania                                    0.863513
# Ministério da Ciência, Tecnologia, Inovações               5.352769
# Ministério da Defesa                                       1.014242
# Ministério da Economia                                   364.183505
# Ministério da Educação                                     9.896832
# Ministério da Infraestrutura                              11.426646
# Ministério da Justiça e Segurança Pública                  5.762531
# Ministério da Mulher, Família e Direitos Huma              0.001729
# Ministério da Pesca e Aquicultura                        369.932976
# Ministério da Previdência Social                           0.121495
# Ministério da Saúde                                        1.364386
# Ministério das Comunicações                                1.674016
# Ministério das Mulheres, Igualdade Racial, da             43.080702
# Ministério das Relações Exteriores                         0.452708
# Ministério de Minas e Energia                              2.766685
# Ministério do Desenvolvimento Agrário                      0.528529
# Ministério do Desenvolvimento Regional                    12.119144
# Ministério do Esporte                                      6.537415
# Ministério do Meio Ambiente                               60.906837
# Ministério do Trabalho e Emprego                           2.900730
# Ministério do Turismo                                      0.904245
# Presidência da República                                   0.215032
#
#                                                ano_ejercicio
# nombre_organo_superior
# Advocacia-Geral da União                         2016.513209
# Controladoria-Geral da União                     2016.281746
# Ministério da Agricultura, Pecuária e Abastec    2018.179741
# Ministério da Cidadania                          2017.563242
# Ministério da Ciência, Tecnologia, Inovações     2018.313339
# Ministério da Defesa                             2018.312808
# Ministério da Economia                           2018.529313
# Ministério da Educação                           2018.088486
# Ministério da Infraestrutura                     2018.285810
# Ministério da Justiça e Segurança Pública        2018.320810
# Ministério da Mulher, Família e Direitos Huma    2018.681936
# Ministério da Pesca e Aquicultura                2015.852547
# Ministério da Previdência Social                 2015.897196
# Ministério da Saúde                              2018.115803
# Ministério das Comunicações                      2018.173388
# Ministério das Mulheres, Igualdade Racial, da    2016.112281
# Ministério das Relações Exteriores               2017.998597
# Ministério de Minas e Energia                    2018.289295
# Ministério do Desenvolvimento Agrário            2016.163664
# Ministério do Desenvolvimento Regional           2018.046478
# Ministério do Esporte                            2016.571429
# Ministério do Meio Ambiente                      2018.358801
# Ministério do Trabalho e Emprego                 2015.966423
# Ministério do Turismo                            2018.076929
# Presidência da República                         2017.602492

# %%
df_all[df_all['nombre_organo_superior'].str.contains('Presidência da República')]
# Out:
#        codigo_organo_superior    nombre_organo_superior codigo_organo  \
# 4462                    20000  Presidência da República         20101
# 4463                    20000  Presidência da República         67000
# 4464                    20000  Presidência da República         20101
# 4465                    20000  Presidência da República         64000
# 4466                    20000  Presidência da República         20116
# ...                       ...                       ...           ...
# 134588                  20000  Presidência da República         24208
# 134589                  20000  Presidência da República         24208
# 134590                  20000  Presidência da República         24208
# 134591                  20000  Presidência da República         24208
# 134592                  20000  Presidência da República         24208
#
#                                             nombre_organo  \
# 4462                             Presidência da República
# 4463    Secretaria de Políticas de Promoção da Igualda...
# 4464                             Presidência da República
# 4465                       Secretaria de Direitos Humanos
# 4466                           Fundo de Imprensa Nacional
# ...                                                   ...
# 134588     Instituto Nacional de Tecnologia da Informação
# 134589     Instituto Nacional de Tecnologia da Informação
# 134590     Instituto Nacional de Tecnologia da Informação
# 134591     Instituto Nacional de Tecnologia da Informação
# 134592     Instituto Nacional de Tecnologia da Informação
#
#        codigo_unidad_gestora                          nombre_unidad_gestora  \
# 4462                  110005  SECRETARIA DE ADMINISTRACAO-SET.ORC.E FIN./PR
# 4463                  238012  SECRETARIA DE POLIT. DE PROM.DA IGUALD.RACIAL
# 4464                  110005  SECRETARIA DE ADMINISTRACAO-SET.ORC.E FIN./PR
# 4465                  200016              SECRETARIA DE DIREITOS HUMANOS/PR
# 4466                  110245    FUNDO DE IMPRENSA NACIONAL/EXEC.ORC.FINANC.
# ...                      ...                                            ...
# 134588                243001  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI
# 134589                243001  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI
# 134590                243001  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI
# 134591                243001  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI
# 134592                243001  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI
#
#         categoria_economica              origen_receta  \
# 4462     Receitas Correntes  Outras Receitas Correntes
# 4463     Receitas Correntes  Outras Receitas Correntes
# 4464     Receitas Correntes  Outras Receitas Correntes
# 4465     Receitas Correntes  Outras Receitas Correntes
# 4466     Receitas Correntes  Outras Receitas Correntes
# ...                     ...                        ...
# 134588  Receitas de Capital       Operações de Crédito
# 134589   Receitas Correntes        Receita de Serviços
# 134590   Receitas Correntes        Receita de Serviços
# 134591   Receitas Correntes        Receita de Serviços
# 134592   Receitas Correntes        Receita de Serviços
#
#                                       especie_receta  \
# 4462                       Demais receitas correntes
# 4463     Indenizações, restituições e ressarcimentos
# 4464     Indenizações, restituições e ressarcimentos
# 4465     Indenizações, restituições e ressarcimentos
# 4466     Indenizações, restituições e ressarcimentos
# ...                                              ...
# 134588        Operações de crédito - mercado interno
# 134589  Serviços Administrativos e Comerciais Gerais
# 134590  Serviços Administrativos e Comerciais Gerais
# 134591  Serviços Administrativos e Comerciais Gerais
# 134592  Serviços Administrativos e Comerciais Gerais
#
#                                        detallamiento  \
# 4462                                VARIACAO CAMBIAL
# 4463    RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# 4464    RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# 4465    RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# 4466    RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# ...                                              ...
# 134588  TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.
# 134589  SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 134590  SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 134591  SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 134592  SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
#
#         valor_previsto_actualizado  valor_lanzado  valor_realizado  \
# 4462                           0.0            0.0           292.34
# 4463                           0.0            0.0          3939.94
# 4464                           0.0            0.0        377364.36
# 4465                           0.0            0.0         49142.06
# 4466                           0.0            0.0            90.00
# ...                            ...            ...              ...
# 134588                  16940891.0            0.0             0.00
# 134589                         0.0            0.0           372.90
# 134590                    200000.0            0.0             0.00
# 134591                         0.0            0.0       1000000.00
# 134592                         0.0            0.0       1000000.00
#
#         percentual_realizado fecha_lanzamiento  ano_ejercicio
# 4462                     0.0        2013-12-31           2013
# 4463                     0.0        2013-12-31           2013
# 4464                     0.0        2013-12-31           2013
# 4465                     0.0        2013-12-31           2013
# 4466                     0.0        2013-12-31           2013
# ...                      ...               ...            ...
# 134588                   0.0        2021-04-23           2021
# 134589                   0.0        2021-11-22           2021
# 134590                   0.0        2021-04-23           2021
# 134591                   0.0        2021-05-10           2021
# 134592                   0.0        2021-03-23           2021
#
# [4976 rows x 16 columns]

# %% [markdown]
# #### En vista de lo anterior, el valor lanzado contiene muchos 0. Hay muchos ministerios que no tienen valor lanzado. Puede que esta clumna sea poco relevante.

# %% [markdown]
# ## Explorar los valores mas altos

# %%
## valor_previsto_actualizado	valor_lanzado	valor_realizado	percentual_realizado
columnas_valores = ['ano_ejercicio','valor_previsto_actualizado','valor_lanzado','valor_realizado','percentual_realizado']
df_valores = df_all[columnas_valores]
df_valores.groupby('ano_ejercicio').mean().sort_values(by="percentual_realizado", ascending=False)
# Out:
#                valor_previsto_actualizado  valor_lanzado  valor_realizado  \
# ano_ejercicio
# 2014                         5.253963e+08   2.781816e+08     4.916651e+08
# 2013                         4.834706e+08   2.540144e+08     4.209902e+08
# 2015                         6.364863e+08   6.794088e+07     5.893622e+08
# 2020                         2.514478e+07   2.501662e+05     2.552648e+07
# 2019                         1.845277e+07  -7.054622e+05     1.692617e+07
# 2017                         1.793333e+07   7.035409e+05     1.343562e+07
# 2016                         1.518478e+07   9.591932e+04     1.460374e+07
# 2021                         3.109033e+07  -4.712324e+04     2.882704e+07
# 2018                         2.016722e+07   4.903495e+04     1.692691e+07
#
#                percentual_realizado
# ano_ejercicio
# 2014                   16765.438612
# 2013                     999.233882
# 2015                     336.481539
# 2020                       0.283203
# 2019                       0.181372
# 2017                       0.010016
# 2016                       0.008208
# 2021                       0.002462
# 2018                       0.001749

# %%
df_valores.plot(x='ano_ejercicio')
# Out:
# <Axes: xlabel='ano_ejercicio'>

# %% [markdown]
# ### Encontrar outliers usando boxplots

# %%
## valor_previsto_actualizado	valor_lanzado	valor_realizado	percentual_realizado
columnas_valores2 = ['valor_previsto_actualizado','valor_lanzado','valor_realizado']
df_valores2 = df_all[columnas_valores2]
df_valores2.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# ## Los problemas concretos que te han pedido resolver son:
#
# 1.	**Desviaciones entre lo previsto y lo recaudado**: Determinar en qué categorías económicas o tipos de ingresos las diferencias son más pronunciadas.
#
# 2.	**Evolución temporal de la recaudación**: Identificar cómo han cambiado las previsiones y recaudaciones año a año, y si existen patrones temporales, como meses específicos donde hay mayores discrepancias.
#
# 3.	**Rendimiento por órgano y unidad gestora**: Evaluar qué órganos o unidades gestoras son más eficientes en términos de alcanzar las metas de recaudación y cuáles presentan consistentemente una baja ejecución.

# %% [markdown]
# ### 1.	**Desviaciones entre lo previsto y lo recaudado**: Determinar en qué categorías económicas o tipos de ingresos las diferencias son más pronunciadas.

# %% [markdown]
# - `valor_previsto_actualizado`: Monto actualizado del ingreso previsto (formato texto).
#
# - `valor_lanzado`: Monto que fue registrado como lanzado (formato texto).
#
# - `valor_realizado`: Monto realmente recaudado (formato texto).
#
# - `año de ejercicio`: Año correspondiente a la ejecución de los ingresos.

# %% [markdown]
# 1. **Distribución de Ingresos por Categoría Económica:**
#
#    - Analizar las categorías de ingresos más significativas y su participación en los ingresos totales.
#
#    - Calcular la diferencia promedio entre ingresos previstos y realizados por cada categoría.

# %%
## Analizar las categorias de ingresos mas significativas y su participacion en los ingresos totales
# Receitas Correntes abarcan todos los ingresos corrientes externos e internos del gobierno, 
# mientras que Receitas Correntes - Intra-orçamentárias se limitan a aquellos ingresos que se 
# generan por transacciones internas dentro del sistema presupuestario gubernamental.

df_all.columns
columnas_valores = ['categoria_economica','valor_previsto_actualizado','valor_lanzado','valor_realizado','percentual_realizado']
df_valores = df_all[columnas_valores]
df_categorias = df_valores.groupby('categoria_economica').mean().sort_values(by="percentual_realizado", ascending=False)
df_categorias.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='categoria_economica'>

# %%
# Calcular el total de la columna 'Valor'

calcular_porcentajes(df_categorias, ['valor_previsto_actualizado','valor_lanzado','valor_realizado'])
#df_categorias.drop(columns='Porcentaje', inplace=True)

df_categorias
# Out:
#                                            valor_previsto_actualizado  \
# categoria_economica
# Receitas Correntes                                       1.383874e+07
# Receitas de Capital                                      4.816863e+08
# Receitas Correntes - intra-orçamentárias                 1.795411e+07
# Receitas de Capital - intra-orçamentárias                1.137728e+08
# Sem informação                                           0.000000e+00
#
#                                            valor_lanzado  valor_realizado  \
# categoria_economica
# Receitas Correntes                          2.839846e+06     1.318489e+07
# Receitas de Capital                         7.995999e+00     4.125673e+08
# Receitas Correntes - intra-orçamentárias    0.000000e+00     1.802598e+07
# Receitas de Capital - intra-orçamentárias   0.000000e+00     2.973772e+08
# Sem informação                              7.423116e+06     2.146083e-01
#
#                                            percentual_realizado  \
# categoria_economica
# Receitas Correntes                                    82.750971
# Receitas de Capital                                   40.590929
# Receitas Correntes - intra-orçamentárias              11.317277
# Receitas de Capital - intra-orçamentárias              0.000000
# Sem informação                                         0.000000
#
#                                            Porcentaje_valor_previsto_actualizado  \
# categoria_economica
# Receitas Correntes                                                      2.206249
# Receitas de Capital                                                    76.793120
# Receitas Correntes - intra-orçamentárias                                2.862345
# Receitas de Capital - intra-orçamentárias                              18.138286
# Sem informação                                                          0.000000
#
#                                            Porcentaje_valor_lanzado  \
# categoria_economica
# Receitas Correntes                                        27.670798
# Receitas de Capital                                        0.000078
# Receitas Correntes - intra-orçamentárias                   0.000000
# Receitas de Capital - intra-orçamentárias                  0.000000
# Sem informação                                            72.329124
#
#                                            Porcentaje_valor_realizado
# categoria_economica
# Receitas Correntes                                       1.778965e+00
# Receitas de Capital                                      5.566543e+01
# Receitas Correntes - intra-orçamentárias                 2.432146e+00
# Receitas de Capital - intra-orçamentárias                4.012346e+01
# Sem informação                                           2.895591e-08
